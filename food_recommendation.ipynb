# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
data = pd.read_csv("food.csv")

# %%
data.head(1)
# Out:
#                                  name  \
# 0  Thayir Semiya Recipe (Curd Semiya)
#
#                                            image_url  \
# 0  https://www.archanaskitchen.com/images/archana...
#
#                                          description cuisine course  \
# 0  Thayir Semiya or Curd Vermicelli is a quick di...  Indian  Lunch
#
#          diet      prep_time  \
# 0  Vegetarian  Total in 35 M
#
#                                          ingredients  \
# 0  \n\n\t\t\t\t\t\t\t \t\t1/2 cup Semiya (Vermice...
#
#                                         instructions
# 0  To begin making the Thayir Semiya recipe, firs...

# %%
data.drop_duplicates(inplace=True)

# %%
data["ingredients_a"] = data["ingredients"].apply(lambda x: " ".join(x.split()))

# %%
data.to_csv("clean_data.csv")

# %%
cv = TfidfVectorizer()
tfid = cv.fit_transform(data["ingredients_a"])

# %%
consin_sim = linear_kernel(tfid,tfid)

# %%
def recommendation(name):
    mm = []
    ind = data[data["name"]==name].index[0]
    rec =  list(enumerate(consin_sim[ind]))
    rec = sorted(rec,reverse=True,key=lambda x : x[1])
    rec = rec[0:10]
    for i in rec:
        mm.append(data.iloc[i[0]])  
        df = pd.DataFrame(mm)
    return df

# %%
recommendation("Mangalorean Chana Gassi Recipe")
# Out:
#                                                    name  \
# 26                       Mangalorean Chana Gassi Recipe
# 466   Maharastrian Kairichi Amti Recipe - Raw Mango ...
# 2858  Kale Chane Ki Kadhi Recipe - Black Chickpea Ka...
# 1259  Menthya Matvadi Palya Recipe - Madhwa Brahmin ...
# 2946  Mavinakayi Chutney Recipe - South Canara Raw M...
# 80    Mangalorean Style Sonay Sukka Recipe - Dry Chi...
# 1753          Sukhe Chole Recipe - Dry Masala Chickpeas
# 193   Kondakadalai Vazhathandu Puli Thengai Kuzhambu...
# 3801                      Chickpea Tikka Masala Recipe
# 293   Mavinakayi Menasinakai Curry Recipe  - Raw Man...
#
#                                               image_url  \
# 26    https://www.archanaskitchen.com/images/archana...
# 466   https://www.archanaskitchen.com/images/archana...
# 2858  https://www.archanaskitchen.com/images/archana...
# 1259  https://www.archanaskitchen.com/images/archana...
# 2946  https://www.archanaskitchen.com/images/archana...
# 80    https://www.archanaskitchen.com/images/archana...
# 1753  https://www.archanaskitchen.com/images/archana...
# 193   https://www.archanaskitchen.com/images/archana...
# 3801  https://www.archanaskitchen.com/images/archana...
# 293   https://www.archanaskitchen.com/images/archana...
#
#                                             description  \
# 26    Mangalorean Chana Gassi Recipe is an authentic...
# 466   Maharashtrian Kairichi Amti Recipe (Gravied Gr...
# 2858  Kale Chane Ki Kadhi is a creamy spiced yogurt ...
# 1259  Matwadi Palya Recipe is essentially a Madhwa B...
# 2946  South Canara Style Mavinakayi Hindi Recipe (Ra...
# 80    Mangalorean Style Sonay Sukhe is a very import...
# 1753  This Sukhe Chole is a simple high protein reci...
# 193   Kondakadalai Vazhathandu Puli Thengai Kuzhambu...
# 3801  Chickpea Tikka Masala Recipe is a vegetarian v...
# 293   Mangalorean Mavinakayi Menasinakai Curry Recip...
#
#                     cuisine       course                     diet  \
# 26              Mangalorean    Side Dish  High Protein Vegetarian
# 466   Maharashtrian Recipes    Side Dish               Vegetarian
# 2858   North Indian Recipes       Dinner               Vegetarian
# 1259              Karnataka    Side Dish        Diabetic Friendly
# 2946              Karnataka    Side Dish               Vegetarian
# 80              Mangalorean        Lunch               Vegetarian
# 1753                Punjabi        Lunch  High Protein Vegetarian
# 193              Tamil Nadu  Main Course        Diabetic Friendly
# 3801   North Indian Recipes        Lunch  High Protein Vegetarian
# 293             Mangalorean    Side Dish               Vegetarian
#
#            prep_time                                        ingredients  \
# 26     Total in 35 M  \n\n\t\t\t\t\t\t\t \t\t1 cup Kabuli Chana (Whi...
# 466    Total in 40 M  \nFor the fresh coconut masala\n\n\t\t\t\t\t\t...
# 2858   Total in 55 M  \n\n\t\t\t\t\t\t\t \t\t1/2 cup Kala Chana (Bro...
# 1259  Total in 135 M  \n\n\t\t\t\t\t\t\t \t\t50 grams Methi Leaves (...
# 2946   Total in 15 M  \n\n\t\t\t\t\t\t\t \t\t2 Mango (Raw)\t\t\t\t\t...
# 80     Total in 55 M  \n\n\t\t\t\t\t\t\t \t\t1 cup Kabuli Chana (Whi...
# 1753   Total in 40 M  \n\n\t\t\t\t\t\t\t \t\t1 cup Kabuli Chana (Whi...
# 193   Total in 530 M  \n\n\t\t\t\t\t\t\t \t\t1 cup Kala Chana (Brown...
# 3801   Total in 65 M  \n\n\t\t\t\t\t\t\t \t\t1 cup Kabuli Chana (Whi...
# 293    Total in 35 M  \n\n\t\t\t\t\t\t\t \t\t1 cup Mango (Raw)\t\t\t...
#
#                                            instructions  \
# 26    To begin making Mangalorean Chana Gassi Recipe...
# 466   To begin Maharashtrian Kairichi Amti Recipe, w...
# 2858  To begin making the Kale Chane Ki Kadhi Recipe...
# 1259  To prepare Matwadi Palya Recipe (Madhwa Brahmi...
# 2946  To begin making Mavinakayi Chutney Recipe, tak...
# 80    To begin making the Mangalorean Style Sonay Su...
# 1753  To begin making the Sukhe Chole Recipe, cook t...
# 193   We begin making the Kondakadalai Vazhathandu P...
# 3801  To begin making the Chickpea Tikka Masala, we ...
# 293   To begin making Mangalorean Mavinakayi Menasin...
#
#                                           ingredients_a
# 26    1 cup Kabuli Chana (White Chickpeas) , soaked ...
# 466   For the fresh coconut masala 1/2 cup Fresh coc...
# 2858  1/2 cup Kala Chana (Brown Chickpeas) , soaked ...
# 1259  50 grams Methi Leaves (Fenugreek Leaves) 1 tab...
# 2946  2 Mango (Raw) , chopped 5 Dry Red Chillies 1/2...
# 80    1 cup Kabuli Chana (White Chickpeas) , soaked ...
# 1753  1 cup Kabuli Chana (White Chickpeas) , soaked ...
# 193   1 cup Kala Chana (Brown Chickpeas) , soaked in...
# 3801  1 cup Kabuli Chana (White Chickpeas) , soaked ...
# 293   1 cup Mango (Raw) , diced 2 tablespoons Jagger...

# %%
d["name"][2]
# Out:
# 'Goan Chana Ros Recipe (White Peas Curry)'
